# %%
import os
import sys
import time

verbose  = os.environ.get('RADICAL_PILOT_VERBOSE', 'REPORT')
os.environ['RADICAL_PILOT_VERBOSE'] = verbose

import radical.pilot as rp
import radical.utils as ru

from rose.rl.learner import SequentialReinforcementLearner
from rose.engine import Task, ResourceEngine
from rose.metrics import GREATER_THAN_THRESHOLD

# %%
engine = ResourceEngine({'runtime': 30,
                         'resource': 'local.localhost'})
rl = SequentialReinforcementLearner(engine)
code_path = f'{sys.executable} {os.getcwd()}'
data_path = os.path.join(os.getcwd(), 'data')
os.makedirs(data_path, exist_ok=True)
# Out:
# Resource Engine started successfully
#
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000000 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000001 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000002 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000003 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000004 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000005 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000006 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000007 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000008 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000009 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000010 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000011 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000012 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000013 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000014 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000015 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000016 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000017 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000018 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000019 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000020 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000021 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000022 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000023 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000024 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000025 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000026 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000027 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000028 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000029 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000030 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000031 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000032 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000033 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000034 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000035 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000036 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000037 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000038 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000039 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000040 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000041 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000042 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000043 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000044 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000045 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000046 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000047 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000048 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000049 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000050 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000051 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000052 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000053 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000054 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000055 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000056 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000057 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000058 is DONE
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000059 is DONE
# Task 'environment' ready to submit; resolved dependencies: []
# submitting ['environment'] for execution
# task.000060 is DONE
# Task 'update' ready to submit; resolved dependencies: ['environment']
# submitting ['update'] for execution
# task.000061 is FAILED
# Task 'check_reward' ready to submit; resolved dependencies: ['update']
# submitting ['check_reward'] for execution
# task.000062 is FAILED

# %%
# Define and register the environment task
@rl.environment_task
def environment(*args):
    return Task(executable=f'{code_path}/simulate.py', arguments=args)

# Define and register the policy update task
@rl.update_task
def update(*args):
    return Task(executable=f'{code_path}/train.py', arguments=args)

@rl.as_stop_criterion(metric_name='MODEL_REWARD', threshold=200, operator=GREATER_THAN_THRESHOLD)
def check_reward(*args):
    return Task(executable=f'{code_path}/test_model.py', arguments=args)

# %%
env = environment()
upd = update()
stop_cond = check_reward()

# %%
rl.learn()
# Out:
# Starting Iteration-0
# Registered task 'environment' and id of 000000 with dependencies: []
# Registered task 'update' and id of 000001 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000002 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (0.43).
# Starting Iteration-1
# Registered task 'environment' and id of 000003 with dependencies: []
# Registered task 'update' and id of 000004 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000005 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (0.13).
# Starting Iteration-2
# Registered task 'environment' and id of 000006 with dependencies: []
# Registered task 'update' and id of 000007 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000008 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (8.24).
# Starting Iteration-3
# Registered task 'environment' and id of 000009 with dependencies: []
# Registered task 'update' and id of 000010 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000011 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.75).
# Starting Iteration-4
# Registered task 'environment' and id of 000012 with dependencies: []
# Registered task 'update' and id of 000013 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000014 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.31).
# Starting Iteration-5
# Registered task 'environment' and id of 000015 with dependencies: []
# Registered task 'update' and id of 000016 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000017 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.22).
# Starting Iteration-6
# Registered task 'environment' and id of 000018 with dependencies: []
# Registered task 'update' and id of 000019 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000020 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.29).
# Starting Iteration-7
# Registered task 'environment' and id of 000021 with dependencies: []
# Registered task 'update' and id of 000022 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000023 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.05).
# Starting Iteration-8
# Registered task 'environment' and id of 000024 with dependencies: []
# Registered task 'update' and id of 000025 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000026 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (64.27).
# Starting Iteration-9
# Registered task 'environment' and id of 000027 with dependencies: []
# Registered task 'update' and id of 000028 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000029 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.1).
# Starting Iteration-10
# Registered task 'environment' and id of 000030 with dependencies: []
# Registered task 'update' and id of 000031 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000032 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.87).
# Starting Iteration-11
# Registered task 'environment' and id of 000033 with dependencies: []
# Registered task 'update' and id of 000034 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000035 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (29.48).
# Starting Iteration-12
# Registered task 'environment' and id of 000036 with dependencies: []
# Registered task 'update' and id of 000037 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000038 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (28.99).
# Starting Iteration-13
# Registered task 'environment' and id of 000039 with dependencies: []
# Registered task 'update' and id of 000040 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000041 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (34.05).
# Starting Iteration-14
# Registered task 'environment' and id of 000042 with dependencies: []
# Registered task 'update' and id of 000043 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000044 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (33.77).
# Starting Iteration-15
# Registered task 'environment' and id of 000045 with dependencies: []
# Registered task 'update' and id of 000046 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000047 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (63.71).
# Starting Iteration-16
# Registered task 'environment' and id of 000048 with dependencies: []
# Registered task 'update' and id of 000049 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000050 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (64.32).
# Starting Iteration-17
# Registered task 'environment' and id of 000051 with dependencies: []
# Registered task 'update' and id of 000052 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000053 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (64.47).
# Starting Iteration-18
# Registered task 'environment' and id of 000054 with dependencies: []
# Registered task 'update' and id of 000055 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000056 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (64.05).
# Starting Iteration-19
# Registered task 'environment' and id of 000057 with dependencies: []
# Registered task 'update' and id of 000058 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000059 with dependencies: ['update']
# stop criterion metric: MODEL_REWARD is not met yet (64.19).
# Starting Iteration-20
# Registered task 'environment' and id of 000060 with dependencies: []
# Registered task 'update' and id of 000061 with dependencies: ['environment']
# Registered task 'check_reward' and id of 000062 with dependencies: ['update']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 rl.learn()
#
# File ~/HPC/exaenv/lib/python3.11/site-packages/rose/rl/learner.py:233, in SequentialReinforcementLearner.learn(self, max_iter)
#     229 update_task = self._register_task(self.update_function, deps=env_task)
#     231 test_task = self._register_task(self.test_function, deps=update_task)
# --> 233 test_result = test_task.result()
#     234 should_stop, _ = self._check_stop_criterion(test_result)
#     235 if should_stop:
#
# File /usr/lib/python3.11/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# Exception: Traceback (most recent call last):
#   File "/home/andrew/HPC/ROSE/examples/rl/mujoco/test_model.py", line 19, in <module>
#     with open("trained_policy.pkl", "rb") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 40] Too many levels of symbolic links: 'trained_policy.pkl'

# %%
engine.shutdown()
# Out:
# Shutdown is triggered, terminating the resources gracefully

# %%
import matplotlib.pyplot as plt
reward_values = rl.get_result(task_name='check_reward')
reward_values = [float(reward.strip()) for reward in reward_values]

plt.figure(figsize=(10, 6))
plt.plot(reward_values, marker='o', color='b', linestyle='-', markersize=6)

# Add labels and title
plt.xlabel('Iteration')
plt.ylabel('Reward')
plt.title('Reward Values for Cart Pole')
